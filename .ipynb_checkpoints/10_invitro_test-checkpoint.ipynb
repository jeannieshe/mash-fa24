# %%
import pandas as pd
import pickle
metadata = pd.read_csv("datasets/metadata_MPS.csv")
X = pd.read_csv("datasets/X_MPS.csv", index_col=0) # genes on the columns, samples on the rows

# %%
metadata
# Out:
#                      Unnamed: 0                           X  \
# 0     NAFT18012_P1A1_D14_49_S18   NAFT18012_P1A1_D14_49_S18
# 1     NAFT18012_P1A2_D14_50_S21   NAFT18012_P1A2_D14_50_S21
# 2      NAFT18012_P1A3_D14_51_S1    NAFT18012_P1A3_D14_51_S1
# 3      NAFT18012_P1A4_D14_52_S4    NAFT18012_P1A4_D14_52_S4
# 4      NAFT18012_P1A5_D14_53_S7    NAFT18012_P1A5_D14_53_S7
# ..                          ...                         ...
# 174   NAFT18014_P5A3_D14_135_S7   NAFT18014_P5A3_D14_135_S7
# 175   NAFT18014_P5A6_D14_138_S8   NAFT18014_P5A6_D14_138_S8
# 176   NAFT18014_P5B3_D14_141_S9   NAFT18014_P5B3_D14_141_S9
# 177  NAFT18014_P5B6_D14_144_S10  NAFT18014_P5B6_D14_144_S10
# 178  NAFT18015_P1B3_D14_153_S11  NAFT18015_P1B3_D14_153_S11
#
#                      sampleName                 condition  \
# 0     NAFT18012_P1A1_D14_49_S18              Lean_control
# 1     NAFT18012_P1A2_D14_50_S21              Lean_control
# 2      NAFT18012_P1A3_D14_51_S1              Lean_control
# ...

# %%
X
# Out:
#                               TSPAN6      TNMD      DPM1     SCYL3  C1orf112  \
# NAFT18012_P1A1_D14_49_S18   0.314171 -0.028941 -0.317265  0.399296  0.325326
# NAFT18012_P1A2_D14_50_S21  -0.564131 -0.028941  0.182561  0.172747  0.361327
# NAFT18012_P1A3_D14_51_S1   -0.732356 -0.028941  0.106407 -0.010675 -0.088335
# NAFT18012_P1A4_D14_52_S4   -0.186960 -0.028941  0.026812 -0.004851 -0.002923
# NAFT18012_P1A5_D14_53_S7    0.136032 -0.028941  0.109943 -0.157335 -0.032552
# ...                              ...       ...       ...       ...       ...
# NAFT18014_P5A3_D14_135_S7  -0.303164 -0.028941  0.069720 -0.118959  0.391970
# NAFT18014_P5A6_D14_138_S8   0.092090 -0.028941 -0.227362 -0.018526  0.103275
# NAFT18014_P5B3_D14_141_S9   0.972188  0.916163  0.036054  0.218776  0.541312
# NAFT18014_P5B6_D14_144_S10  1.491488  0.141006  0.146798 -0.010322  0.400937
# NAFT18015_P1B3_D14_153_S11 -0.358311 -0.028941  0.086445  0.089677  0.141273
#
# ...

# %%
# use in vitro dataset as input for PLSR-trained on Pantano data model
# load the models

loaded_models = []
for i in range(0, 10):
    filename = f"models/{training_dataset}_PLSR_fold_{i}.pkl"
    with open(filename, 'rb') as file:
        model = pickle.load(file)
        loaded_models.append(model)
    print(f"Loaded model {i} from {filename}")
